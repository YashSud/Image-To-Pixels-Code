# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
import os
print(os.listdir())
# Out:
# ['.bash_history', '.cache', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.vscode', '3D Objects', 'AppData', 'Application Data', 'BostonData.ipynb', 'CancerDetails.ipynb', 'Contacts', 'Cookies', 'CrossDevice', 'DiabetesPatients.ipynb', 'Documents', 'Downloads', 'Employee.ipynb', 'Favorites', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{4c5c179a-e477-11ef-a58c-93625ef0ac09}.TM.blf', 'NTUSER.DAT{4c5c179a-e477-11ef-a58c-93625ef0ac09}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{4c5c179a-e477-11ef-a58c-93625ef0ac09}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'obj_detection.py', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'scikit_learn_data', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Tensorflow.ipynb', 'tic_tac_toe.db', 'Tic_Tac_Toe.ipynb', 'Untitled-1.py', 'Untitled.ipynb', 'untitled.py', 'Untitled1.ipynb', 'Untit
# ...

# %%
import urllib.request
urllib.request.urlretrieve("https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz", "cifar-10-python.tar.gz")
# Out:
# ('cifar-10-python.tar.gz', <http.client.HTTPMessage at 0x2dd8a086490>)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\Yash Sud\OneDrive\Pictures\download.jpeg")  # Load image
plt.imshow(img)  # Display image
plt.axis("off")  # Hide axes
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))  # 1 row, 3 columns
for i in range(3):
    img = np.random.rand(32, 32, 3)  # Generate random images
    axes[i].imshow(img)
    axes[i].axis("off")
plt.show()

# %%
with open("cifar-10-batches-py/data_batch_1", "rb") as f:
    batch = pickle.load(f, encoding="bytes")

# %%
import urllib.request
import tarfile

# Download CIFAR-10 dataset
url = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
file_path = "cifar-10-python.tar.gz"

print("Downloading CIFAR-10 dataset...")
urllib.request.urlretrieve(url, file_path)

# Extract the dataset
print("Extracting files...")
with tarfile.open(file_path, "r:gz") as tar:
    tar.extractall()

print("Download and extraction complete!")
# Out:
# ...
# Extracting files...
# Download and extraction complete!

# %%
with open("cifar-10-batches-py/data_batch_1", "rb") as f:
    batch = pickle.load(f, encoding="bytes")

# %%
import pickle

# Load CIFAR-10 batch
with open("cifar-10-batches-py/data_batch_1", "rb") as f:
    batch = pickle.load(f, encoding="bytes")

# Extract image data
images = batch[b"data"].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)  # Convert to (N, 32, 32, 3)

# Display first 5 images
fig, axes = plt.subplots(1, 5, figsize=(10, 2))
for i in range(5):
    axes[i].imshow(images[i])
    axes[i].axis("off")
plt.show()
